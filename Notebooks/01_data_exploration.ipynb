# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve
)
print("Everything working")
# Out:
# Everything working

# %%
df = pd.read_csv("../data/raw/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ## checking missing values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ###  data set checked for missing values , no significat missing values were identified so no action required

# %% [markdown]
# ## check for duplicate values ##

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df[df.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# duplicates are removed -Now dataset contains 283726 transactions after removing duplicates

# %% [markdown]
# #  check data types #

# %%
####  check data types #####

df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
#### Analyze Fraud vs Legitimate Transactions ###
df["Class"].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
df["Class"].value_counts(normalize=True)*100
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
## visualization ##
sns.countplot(x="Class",data = df)
plt.title("Distribution of the Fraudulent and Legitimate Transactions")
plt.xlabel("transaction Class")
plt.ylabel("No of Transaction")
plt.show()

# %% [markdown]
# ## Week 1 Findings
#
# 1. The dataset contains 284807 transactions after removing duplicates 283726.
# 2. The dataset contains 31 variables.
# 3. The target variable is Class.
# 4. Class 0 represents legitimate transactions.
# 5. Class 1 represents fraudulent transactions.
# 6. The dataset is highly imbalanced.
# 7. Missing-value analysis was performed - no significant missing values.
# 8. Duplicate records were checked - removed 1081 duplicates.
# 9. Data types were reviewed - no issues.
# 10.The dataset is ready for exploratory analysis.

# %% [markdown]
# # Calculate fraud statistics #

# %%
total_transactions = len(df)
fraud_transactions = df["Class"].sum()
fraud_percentage = (fraud_transactions/total_transactions)*100
print("Total transactions:", total_transactions)
print("Fraudulent transactions:", fraud_transactions)
print("Fraud percentage:", fraud_percentage)
# Out:
# Total transactions: 283726
# Fraudulent transactions: 473
# Fraud percentage: 0.1667101358352777

# %% [markdown]
# # Understand Time #

# %%
df["Time"].describe()

# %%
plt.hist(df["Time"], bins=50)
plt.title("Transaction Time Distribution")
plt.xlabel("Time")
plt.ylabel("Number of Transaction")
plt.show()

# %% [markdown]
# # Understand Amount #

# %%
df["Amount"].describe()

# %%
sns.histplot(df["Amount"], bins=50)
plt.title("Transaction Amount Distribution")
plt.show()

# %%
sns.boxplot(x=df["Amount"])
plt.title("Transaction Amount Boxplot")
plt.show()

# %% [markdown]
# # Compare fraud amount vs legitimate amount #

# %%
df.groupby("Class")["Amount"].describe()

# %%
sns.boxplot(x="Class",y="Amount",data=df)
plt.title("Transaction Amount by class")
plt.show()

# %% [markdown]
# # Deep EDA Using Python #

# %%
legit = df[df["Class"] == 0]
fraud = df[df["Class"] == 1]

# %%
legit["Amount"].describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud["Amount"].describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Plot legitimate vs fraud amounts ##

# %%
sns.boxplot(x="Class", y="Amount", data=df)
plt.title("Transaction Amount: Fraud vs Legitimate")
plt.show()
